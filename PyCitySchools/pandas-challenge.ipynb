# %%
import pandas as pd 
from pathlib import Path

# %%
school_data_to_load = Path("Desktop/Resource/schools_complete.csv")
student_data_to_load = Path("Desktop/Resource/students_complete.csv")

# %%
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# %%
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
school_count=school_data["school_name"].count()
school_count
# Out:
# 15

# %%
student_count=student_data["student_name"].count()
student_count
# Out:
# 39170

# %%
total_budget=school_data["budget"].sum()
total_budget
# Out:
# 24649428

# %%
average_math_score = student_data[("math_score")].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
average_reading_score = student_data[("reading_score")].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
passing_math_count = school_data_complete[(school_data_complete["math_score"] >= 70)].count()["student_name"]
passing_math_percentage = passing_math_count / float(student_count) * 100
passing_math_percentage
# Out:
# 74.9808526933878

# %%
passing_reading_count = (school_data_complete["reading_score"]>70)
passing_reading_percentage = passing_reading_count / float(student_count) * 100

# %%
passing_math_reading_count = school_data_complete[
    (school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)
].count()["student_name"]
overall_passing_rate = passing_math_reading_count /  float(student_count) * 100
overall_passing_rate
# Out:
# 65.17232575950983

# %%
district_summary = pd.DataFrame({"Total Schools":[school_count], "Total Students":[student_count],"Total Budget":[total_budget],
                                "Average Math Score":[average_math_score], "Average Reading Score":[average_reading_score], "% Passing Math":[passing_math_percentage],
                                "% Passing Reading":[passing_reading_percentage],"% Overall Passing Rate":[passing_math_reading_count]})

district_summary["Total Students"] = district_summary["Total Students"].map("{:,}".format)
district_summary["Total Budget"] = district_summary["Total Budget"].map("${:,.2f}".format)


district_summary
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  \
# 0               81.87784       74.980853
#
#                                    % Passing Reading  % Overall Passing Rate
# 0  0        0.000000
# 1        0.002553
# 2        0...                   25528

# %%
school_types = school_data.set_index(["school_name"])["type"]
school_types.head()
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Name: type, dtype: object

# %%
per_school_counts = len(school_data_complete["school_name"].unique())
per_school_counts
# Out:
# 15

# %%
per_school_budget = school_data_complete.groupby(["school_name"])["budget"].mean()
per_school_budget
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
student_per_school = school_data_complete["school_name"].value_counts()
student_per_school.head()
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Name: school_name, dtype: int64

# %%
per_student_budget = per_school_budget/student_per_school
per_student_budget
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
per_school_math = school_data_complete.groupby(["school_name"])["math_score"].mean()
per_school_math
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
per_school_reading = school_data_complete.groupby(["school_name"])["reading_score"].mean()
per_school_reading
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
students_passing_math = school_data_complete.loc[school_data_complete["math_score"]>=70]
school_students_passing_math = students_passing_math["school_name"].value_counts()

# %%
students_passing_reading = school_data_complete.loc[school_data_complete["reading_score"]>=70]
school_students_passing_reading = students_passing_reading["school_name"].value_counts()

# %%
students_passing_math_and_reading = school_data_complete[
    (school_data_complete["reading_score"] >= 70) & (school_data_complete["math_score"] >= 70)
]
school_students_passing_math_and_reading = students_passing_math_and_reading.groupby(["school_name"]).size()

# %%
per_school_passing_math = school_students_passing_math / student_per_school * 100
per_school_passing_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: school_name, dtype: float64

# %%
per_school_passing_reading = school_students_passing_reading /student_per_school * 100
per_school_passing_reading
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: school_name, dtype: float64

# %%
overall_passing_rate = school_students_passing_math_and_reading /student_per_school * 100
overall_passing_rate
# Out:
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       90.948012
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
school_summary_df = pd.DataFrame({
                                  "School Type":school_types,
                                  "Total Students":student_per_school,
                                  "Total School Budget":per_school_budget,
                                  "Per Student Budget":per_student_budget,
                                  "Average Math Score":per_school_math,
                                  "Average Reading Score":per_school_reading,
                                  "% Passing Math":per_school_passing_math,
                                  "% Passing Reading":per_school_passing_reading,
                                  "Overall Passing Rate":overall_passing_rate})

school_summary_df = school_summary_df.reset_index(drop=True)
school_summary_df
# Out:
#    School Type  Total Students  Total School Budget  Per Student Budget  \
# 0     District            4976            3124928.0               628.0
# 1      Charter            1858            1081356.0               582.0
# 2     District            2949            1884411.0               639.0
# 3     District            2739            1763916.0               644.0
# 4      Charter            1468             917500.0               625.0
# 5     District            4635            3022020.0               652.0
# 6      Charter             427             248087.0               581.0
# 7     District            2917            1910635.0               655.0
# 8     District            4761            3094650.0               650.0
# 9      Charter             962             585858.0               609.0
# 10    District            3999            2547363.0               637.0
# 11     Charter            1761            1056600.0               600.0
# ...

# %%
top_schools = school_summary_df.sort_values(["% Passing Math","% Passing Reading","Overall Passing Rate" ], 
                                        ascending=False)
top_schools.head()
# Out:
#    School Type  Total Students  Total School Budget  Per Student Budget  \
# 9      Charter             962             585858.0               609.0
# 1      Charter            1858            1081356.0               582.0
# 13     Charter            2283            1319574.0               578.0
# 11     Charter            1761            1056600.0               600.0
# 4      Charter            1468             917500.0               625.0
#
#     Average Math Score  Average Reading Score  % Passing Math  \
# 9            83.839917              84.044699       94.594595
# 1            83.061895              83.975780       94.133477
# 13           83.274201              83.989488       93.867718
# 11           83.359455              83.725724       93.867121
# 4            83.351499              83.816757       93.392371
#
#     % Passing Reading  Overall Passing Rate
# 9           95.945946             90.540541
# 1           97.039828             91.334769
# ...

# %%
bottom_schools = school_summary_df.sort_values("Overall Passing Rate")
bottom_schools.head(5)
# Out:
#    School Type  Total Students  Total School Budget  Per Student Budget  \
# 10    District            3999            2547363.0               637.0
# 2     District            2949            1884411.0               639.0
# 7     District            2917            1910635.0               655.0
# 5     District            4635            3022020.0               652.0
# 8     District            4761            3094650.0               650.0
#
#     Average Math Score  Average Reading Score  % Passing Math  \
# 10           76.842711              80.744686       66.366592
# 2            76.711767              81.158020       65.988471
# 7            76.629414              81.182722       65.683922
# 5            77.289752              80.934412       66.752967
# 8            77.072464              80.966394       66.057551
#
#     % Passing Reading  Overall Passing Rate
# 10          80.220055             52.988247
# 2           80.739234             53.204476
# ...

# %%
ninth_grade_math_scores =student_data.loc[student_data["grade"] == "9th"].groupby(["school_name"])['math_score'].mean()
ninth_grade_math_scores.head()
tenth_grader_math_scores=student_data.loc[student_data["grade"] == "10th"].groupby(["school_name"])['math_score'].mean()
tenth_grader_math_scores.head()
eleventh_grader_math_scores=student_data.loc[student_data["grade"] == "11th"].groupby(["school_name"])["math_score"].mean()
eleventh_grader_math_scores.head()
twelfth_grader_math_scores=student_data.loc[student_data["grade"] == "12th"].groupby(["school_name"])["math_score"].mean()
twelfth_grader_math_scores.head()

#create a DF for Math Scores by Grade
math_scores_by_grade=pd.DataFrame({"9th":math_9th, "10th": math_10th, "11th":math_11th, "12th":math_12th })
math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
ninth_grade_reading_score=student_data.loc[student_data["grade"] == "9th" ].groupby(["school_name"])["reading_score"].mean()
tenth_grader_reading_scores=student_data.loc[student_data["grade"] == "10th" ].groupby(["school_name"])["reading_score"].mean()
eleventh_grader_reading_scores=student_data.loc[student_data["grade"] == "11th" ].groupby(["school_name"])["reading_score"].mean()
twelfth_grader_reading_scores =student_data.loc[student_data["grade"] == "12th" ].groupby(["school_name"])["reading_score"].mean()

reading_scores_by_grade=pd.DataFrame({"9th":read_9th,"10th":read_10th, "11th":read_11th, "12th":read_12th })
reading_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# %%
school_spending_df = per_school_summary.copy()

# %%
school_spending_df["Spending Ranges (Per Student)"] = pd.cut(school_summary_df["Total School Budget"]/school_summary_df["Total Students"]
                                            ,spending_bins , labels=labels)
school_spending_df
scores_per_school=school_summary_df .drop(columns=["Total Students", "Total School Budget","School Type", "Per Student Budget"])
scores_per_school
# Out:
#     Average Math Score  Average Reading Score  % Passing Math  \
# 0            77.048432              81.033963       66.680064
# 1            83.061895              83.975780       94.133477
# 2            76.711767              81.158020       65.988471
# 3            77.102592              80.746258       68.309602
# 4            83.351499              83.816757       93.392371
# 5            77.289752              80.934412       66.752967
# 6            83.803279              83.814988       92.505855
# 7            76.629414              81.182722       65.683922
# 8            77.072464              80.966394       66.057551
# 9            83.839917              84.044699       94.594595
# 10           76.842711              80.744686       66.366592
# 11           83.359455              83.725724       93.867121
# 12           83.418349              83.848930       93.272171
# 13           83.274201              83.989488       93.867718
# ...

# %%
by_spending =scores_per_school.groupby(["Spending Ranges (Per Student)"])
by_spending.mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 by_spending =scores_per_school.groupby(["Spending Ranges (Per Student)"])
#       2 by_spending.mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
school_summary_df.head()
# Out:
#   School Type  Total Students  Total School Budget  Per Student Budget  \
# 0    District            4976            3124928.0               628.0
# 1     Charter            1858            1081356.0               582.0
# 2    District            2949            1884411.0               639.0
# 3    District            2739            1763916.0               644.0
# 4     Charter            1468             917500.0               625.0
#
#    Average Math Score  Average Reading Score  % Passing Math  \
# 0           77.048432              81.033963       66.680064
# 1           83.061895              83.975780       94.133477
# 2           76.711767              81.158020       65.988471
# 3           77.102592              80.746258       68.309602
# 4           83.351499              83.816757       93.392371
#
#    % Passing Reading  Overall Passing Rate
# 0          81.933280             54.642283
# 1          97.039828             91.334769
# ...

# %%
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
per_school_summary["School Size"] = pd.cut(school_summary_df["Total Students"],size_bins,labels=labels)
per_school_summary.head()
# Out:
#                                          School Type  \
# 0  school_name
# Huang High School        District
# ...
#
#                                       Total Students  \
# 0  Bailey High School       4976
# Johnson High Sch...
#
#                                  Total School Budget  \
# 0  school_name
# Bailey High School       3124928.0...
#
#                                   Per Student Budget  \
# 0  Bailey High School       628.0
# Cabrera High Sc...
#
#                                   Average Math Score  \
# 0  school_name
# Bailey High School       77.048432...
#
#                                Average Reading Score  \
# 0  school_name
# Bailey High School       81.033963...
#
#                                       % Passing Math  \
# 0  Bailey High School       66.680064
# Cabrera Hig...
#
#                                    % Passing Reading  \
# 0  Bailey High School       81.933280
# Cabrera Hig...
#
# ...

# %%
size_math_scores = per_school_summary.groupby(["School Size"])["Average Math Score"].mean()
size_reading_scores = per_school_summary.groupby(["School Size"])["Average Reading Score"].mean()
size_passing_math = per_school_summary.groupby(["School Size"])["% Passing Math"].mean()
size_passing_reading = per_school_summary.groupby(["School Size"])["% Passing Reading"].mean()
size_overall_passing = per_school_summary.groupby(["School Size"])["% Overall Passing"].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# ...

# %%
size_summary = 
size_summary

# %%
average_math_score_by_type = per_school_summary.groupby(["School Type"])["Average Math Score"].mean()
average_reading_score_by_type = per_school_summary.groupby(["School Type"])["Average Reading Score"].mean()
average_percent_passing_math_by_type = per_school_summary.groupby(["School Type"])["% Passing Math"].mean()
average_percent_passing_reading_by_type = per_school_summary.groupby(["School Type"])["% Passing Reading"].mean()
average_percent_overall_passing_by_type = per_school_summary.groupby(["School Type"])["% Overall Passing"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 average_math_score_by_type = per_school_summary.groupby(["School Type"])["Average Math Score"].mean()
#       2 average_reading_score_by_type = per_school_summary.groupby(["School Type"])["Average Reading Score"].mean()
#       3 average_percent_passing_math_by_type = per_school_summary.groupby(["School Type"])["% Passing Math"].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2183, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2181     return self._numba_agg_general(sliding_mean, engine_kwargs)
#    2182 else:
# -> 2183     result = self._cython_agg_general(
#    2184         "mean",
#    2185         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    2186         numeric_only=numeric_only,
#    2187     )
# ...

# %%
type_summary =
type_summary
